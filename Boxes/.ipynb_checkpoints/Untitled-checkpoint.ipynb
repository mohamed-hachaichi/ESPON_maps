# %%
import geopandas as gpd

# %%
data = gpd.read_file('Boxes/Boxes.shp')

# %%
for col in data.iloc[:,1:3].columns:
    data[col].hist()

# %%
data.iloc[:,1].hist()
# Out:
# <AxesSubplot:>

# %%
data.iloc[:,2].hist()
# Out:
# <AxesSubplot:>

# %%
data.iloc[:,3].hist()
# Out:
# <AxesSubplot:>

# %%
data.iloc[:,3].max()
# Out:
# 2467.299560546875
